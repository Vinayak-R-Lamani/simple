# %%
import pandas as pd

# %%
dataframe = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
dataframe
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 266  E0  26/02/2025  19:30     Man United      Ipswich     3     2   H     2
# 267  E0  26/02/2025  19:30  Nott'm Forest      Arsenal     0     0   D     0
# 268  E0  26/02/2025  19:30      Tottenham     Man City     0     1   A     0
# 269  E0  26/02/2025  20:15      Liverpool    Newcastle     2     0   H     1
# 270  E0  27/02/2025  20:00       West Ham    Leicester     2     0   H     2
#
# ...

# %%
dataframe.rename(columns= {'FTHG':"king",
                           'FTAG':'queen'},inplace= True)

# %%
dataframe
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  king  queen FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1      0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0      2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2      0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0      3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1      0   H     1
# ..   ..         ...    ...            ...          ...   ...    ...  ..   ...
# 266  E0  26/02/2025  19:30     Man United      Ipswich     3      2   H     2
# 267  E0  26/02/2025  19:30  Nott'm Forest      Arsenal     0      0   D     0
# 268  E0  26/02/2025  19:30      Tottenham     Man City     0      1   A     0
# 269  E0  26/02/2025  20:15      Liverpool    Newcastle     2      0   H     1
# 270  E0  27/02/2025  20:00       West Ham    Leicester     2      0   H     2
#
# ...
